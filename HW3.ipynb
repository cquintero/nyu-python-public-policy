# %%
import pandas as pd
pd.set_option('display.max_rows', 200)  # or 1000
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/My Drive/Data for Python/cleaned_311_data.csv', header='infer')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9,18,21,32,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def is_graffiti(row):
  if pd.notnull(row.descriptor) and 'graffiti' in row.descriptor.lower():
    return True
  elif 'graffiti' in row.complaint_type.lower():
    return True
  else:
    return False

#why not just do this all on a sample and not the full dataset?
#you've never explicitly gone over the python 'in' operator so this was confusing
# and I spent awhile down the rabbit hole of pandas str.contains()

#sample = df.sample(10000)
#sample['graffiti_flag'] = sample.apply(is_graffiti, axis=1)
#sample.sort_values(by=['graffiti_flag','complaint_type'], ascending=False)
#sample_graffiti = sample[sample.graffiti_flag]
#sample_graffiti
df['graffiti_flag'] = df.apply(is_graffiti, axis=1)
df_graffiti = df[df.graffiti_flag == True] #I don't understand why the simpler version works?
df_graffiti.groupby('community_board').size()
# Out:
# community_board
# 0 Unspecified                 541
# 01 BRONX                      312
# 01 BROOKLYN                  1797
# 01 MANHATTAN                  146
# 01 QUEENS                     573
# 01 STATEN ISLAND              255
# 02 BRONX                      243
# 02 BROOKLYN                   315
# 02 MANHATTAN                  598
# 02 QUEENS                     219
# 02 STATEN ISLAND               42
# 03 BRONX                      320
# 03 BROOKLYN                  1252
# 03 MANHATTAN                 1593
# 03 QUEENS                     203
# 03 STATEN ISLAND               40
# 04 BRONX                      337
# 04 BROOKLYN                  1429
# 04 MANHATTAN                  307
# 04 QUEENS                     353
# 05 BRONX                      402
# 05 BROOKLYN                   962
# 05 MANHATTAN                  284
# 05 QUEENS                     219
# 06 BRONX                      446
# 06 BROOKLYN                   401
# 06 MANHATTAN                  165
# ...

# %%
df_graffiti.groupby('community_board').size().nlargest(10) #why use nlargest and not sort?
# Out:
# community_board
# 01 BROOKLYN             1797
# 03 MANHATTAN            1593
# 04 BROOKLYN             1429
# 03 BROOKLYN             1252
# 05 BROOKLYN              962
# 07 BROOKLYN              779
# Unspecified BRONX        615
# 02 MANHATTAN             598
# Unspecified BROOKLYN     591
# 01 QUEENS                573
# dtype: int64
